# %%
import read_data
import featureSpan
import Utils
from sklearn.kernel_ridge import KernelRidge
from sklearn.model_selection import train_test_split, cross_val_score, ShuffleSplit
from sklearn.model_selection import GridSearchCV
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error
import scipy.optimize
import scipy.stats as ss
import pandas as pd
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
list1 = read_data.readData("data/DATA_HE_monazite.dat")
print(list1.shape)
# Out:
# (525, 4)

# %%
list2 = read_data.readCSVData("data/Data_Ln.csv",material="monazite")
print(list2.shape)
# Out:
# (15, 8)

# %%
listX, listY = featureSpan.computeMean(list1, list2)
X = np.asarray(listX)
Y = np.asarray(listY)
X = ss.zscore(X)
print(X.shape)
print(Y.shape)
# Out:
# (525, 24)
# (525,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=24)
print(len(X_train),len(X_test), len(y_train), len(y_test))
# Out:
# 393 132 393 132

# %%
cv = ShuffleSplit(n_splits=5, test_size=0.25, random_state=0)

# %% [markdown]
# ### Polynomial Degree 3

# %% [markdown]
# #### My Optimized Hyperparameters

# %%
krp3 = GridSearchCV(
    KernelRidge(kernel="polynomial", gamma=0.1, degree=3),
    param_grid={"alpha": np.logspace(0, 5, 20), "coef0": np.logspace(0, 5, 20), "gamma": np.logspace(0.0, 0.5, 40)},
)

# %%
krp3.fit(X_train.copy(), y_train.copy())
optimized_p3 = krp3.best_estimator_
print(np.log10([optimized_p3.alpha,  optimized_p3.coef0, optimized_p3.gamma]), optimized_p3.kernel)
# Out:
# [0.52631579 2.63157895 0.48717949] polynomial

# %%
#[10.52631579  8.21052632  0.32222222] polynomial
fig, ax =plt.subplots(3,1,figsize=(10,30))
pvt_p3 = pd.pivot_table(pd.DataFrame(krp3.cv_results_), values='mean_test_score', index='param_alpha', columns='param_coef0')
sns.heatmap(pvt_p3,ax=ax[0])
pvt_p3 = pd.pivot_table(pd.DataFrame(krp3.cv_results_), values='mean_test_score', index='param_alpha', columns='param_gamma')
sns.heatmap(pvt_p3,ax=ax[1])
pvt_p3 = pd.pivot_table(pd.DataFrame(krp3.cv_results_), values='mean_test_score', index='param_coef0', columns='param_gamma')
sns.heatmap(pvt_p3,ax=ax[2])
# Out:
# <AxesSubplot:xlabel='param_gamma', ylabel='param_coef0'>

# %%
model_p3=KernelRidge(alpha=optimized_p3.alpha, kernel=optimized_p3.kernel, coef0=optimized_p3.coef0, gamma=optimized_p3.gamma, kernel_params={"degree": 3})

# %%
model_p3.fit(X_train.copy(), y_train.copy())
# Out:
# KernelRidge(alpha=3.3598182862837818, coef0=428.1332398719391,
#             gamma=3.0702906297578494, kernel='polynomial',
#             kernel_params={'degree': 3})

# %%
fit_test_p3 = model_p3.predict(X_test.copy())
fit_train_p3 = model_p3.predict(X_train.copy())

# %%
Utils.print_error(y_test, fit_test_p3, "test set")
Utils.print_error(y_train, fit_train_p3, "train set")
# Out:
# test set
# =========
# Mean absolute error: 0.025904503955167166
# Mean squared error: 0.0016107767695224637
# Max error: 0.18182578598991284
# True value: 0.828152689140625
# Predicted value: 1.0099784751305378
# train set
# =========
# Mean absolute error: 0.0017090953625901737
# Mean squared error: 5.9058267116279854e-06
# Max error: 0.008617788628231038
# True value: 1.7895364802929687
# Predicted value: 1.7809186916647377

# %% [markdown]
# #### cross validation

# %%
score_p3 = cross_val_score(model_p3, X, Y, cv=cv)
print(score_p3)
# Out:
# [0.9965197  0.99937464 0.99879599 0.99923869 0.99919842]

# %%
for train_index, test_index in cv.split(Y):
    fit_test = model_p3.predict(X.copy()[test_index])
    fit_train = model_p3.predict(X.copy()[train_index])
    
    print("--")
    print("### Cross Validation ###")
    print("--")
    Utils.print_error(Y.copy()[train_index], fit_train, "train set")
    Utils.print_error(Y.copy()[test_index], fit_test, "test set")
# Out:
# --
# ### Cross Validation ###
# --
# train set
# =========
# Mean absolute error: 0.008636860579452576
# Mean squared error: 0.0004924248032857857
# Max error: 0.18182578598991284
# True value: 0.828152689140625
# Predicted value: 1.0099784751305378
# test set
# =========
# Mean absolute error: 0.005278657526962728
# Mean squared error: 0.00016227708965727762
# Max error: 0.08251244111622569
# True value: 6.206182393394531
# Predicted value: 6.123669952278306
# --
# ### Cross Validation ###
# --
# train set
# =========
# Mean absolute error: 0.008044883127905647
# Mean squared error: 0.00045049704652700914
# Max error: 0.18182578598991284
# True value: 0.828152689140625
# Predicted value: 1.0099784751305378
# test set
# =========
# Mean absolute error: 0.007041135853013149
# Mean squared error: 0.0002871074563759972
# Max error: 0.10222508669571517
# True value: 0.8487041870195312
# Predicted value: 0.9509292737152464
# --
# ### Cross Validation ###
# --
# train set
# =========
# Mean absolute error: 0.007399664101221203
# Mean squared error: 0.0003855101010709506
# Max error: 0.18182578598991284
# True value: 0.828152689140625
# Predicted value: 1.0099784751305378
# test set
# =========
# Mean absolute error: 0.008962128856575052
# Mean squared error: 0.0004805913166958599
# Max error: 0.11641278192891935
# True value: 1.0204101158125
# Predicted value: 0.9039973338835807
# --
# ### Cross Validation ###
# --
# train set
# =========
# Mean absolute error: 0.007599159842910874
# Mean squared error: 0.0004174802365011352
# Max error: 0.18182578598991284
# True value: 0.828152689140625
# Predicted value: 1.0099784751305378
# test set
# =========
# Mean absolute error: 0.008368175623306495
# Mean squared error: 0.0003854075040031414
# Max error: 0.10222508669571517
# True value: 0.8487041870195312
# Predicted value: 0.9509292737152464
# --
# ### Cross Validation ###
# --
# train set
# =========
# Mean absolute error: 0.008648968507389674
# Mean squared error: 0.0004835046098058913
# Max error: 0.18182578598991284
# True value: 0.828152689140625
# Predicted value: 1.0099784751305378
# test set
# =========
# Mean absolute error: 0.005242608917478673
# Mean squared error: 0.0001888349384212456
# Max error: 0.10219786940698661
# True value: 0.8791921572929687
# Predicted value: 0.9813900266999553

# %% [markdown]
# ### Polynomial Degree 2

# %% [markdown]
# #### My Optimized Hyperparameters

# %%
kr_p2 = GridSearchCV(
    KernelRidge(kernel="polynomial", gamma=0.1, degree=2),
    param_grid={"alpha": np.logspace(-5, 5, 20), "coef0": np.logspace(0, 15, 20), "gamma": np.logspace(0.0, 0.5, 40)},
)

kr_p2.fit(X_train.copy(), y_train.copy())
optimized_p2 = kr_p2.best_estimator_
print(np.log10([optimized_p2.alpha,  optimized_p2.coef0, optimized_p2.gamma]), optimized_p2.kernel)
# Out:
# [-0.78947368  1.57894737  0.5       ] polynomial

# %%
fig, ax =plt.subplots(3,1,figsize=(10,30))
pvt_p2 = pd.pivot_table(pd.DataFrame(kr_p2.cv_results_), values='mean_test_score', index='param_alpha', columns='param_coef0')
sns.heatmap(pvt_p2,ax=ax[0])
pvt_p2 = pd.pivot_table(pd.DataFrame(kr_p2.cv_results_), values='mean_test_score', index='param_alpha', columns='param_gamma')
sns.heatmap(pvt_p2,ax=ax[1])
pvt_p2 = pd.pivot_table(pd.DataFrame(kr_p2.cv_results_), values='mean_test_score', index='param_coef0', columns='param_gamma')
sns.heatmap(pvt_p2,ax=ax[2])
# Out:
# <AxesSubplot:xlabel='param_gamma', ylabel='param_coef0'>

# %%
model_p2=KernelRidge(alpha=optimized_p2.alpha, kernel=optimized_p2.kernel, coef0=optimized_p2.coef0, gamma=optimized_p2.gamma, kernel_params={"degree": 2})

# %%
model_p2.fit(X_train.copy(), y_train.copy())
# Out:
# KernelRidge(alpha=0.1623776739188721, coef0=37.926901907322495,
#             gamma=3.1622776601683795, kernel='polynomial',
#             kernel_params={'degree': 2})

# %%
fit_test_p2 = model_p2.predict(X_test.copy())
fit_train_p2 = model_p2.predict(X_train.copy())

# %%
Utils.print_error(y_test, fit_test_p2, "test set")
Utils.print_error(y_train, fit_train_p2, "train set")
# Out:
# test set
# =========
# Mean absolute error: 0.03472734061623528
# Mean squared error: 0.0031789666203090225
# Max error: 0.24403709549923502
# True value: 0.129717527140625
# Predicted value: -0.11431956835861001
# train set
# =========
# Mean absolute error: 0.0005507350460244127
# Mean squared error: 8.222378372942503e-07
# Max error: 0.004455721486169351
# True value: 1.7895364802929687
# Predicted value: 1.7850807588067994

# %% [markdown]
# #### Cross Validation

# %%
score_p2 = cross_val_score(model_p2, X, Y, cv=cv)
print(score_p2)
# Out:
# [0.99705269 0.99888191 0.99829551 0.99842754 0.99584862]

# %%
for train_index, test_index in cv.split(Y):
    fit_test = model_p2.predict(X.copy()[test_index])
    fit_train = model_p2.predict(X.copy()[train_index])
    
    print("--")
    print("### Cross Validation ###")
    print("--")
    Utils.print_error(Y.copy()[train_index], fit_train, "train set")
    Utils.print_error(Y.copy()[test_index], fit_test, "test set")
# Out:
# --
# ### Cross Validation ###
# --
# train set
# =========
# Mean absolute error: 0.010312421906901612
# Mean squared error: 0.0009743581727866004
# Max error: 0.24403709549923502
# True value: 0.129717527140625
# Predicted value: -0.11431956835861001
# test set
# =========
# Mean absolute error: 0.005664136553635874
# Mean squared error: 0.0002804846321660223
# Max error: 0.10340684729395222
# True value: 1.5817976543828125
# Predicted value: 1.6852045016767647
# --
# ### Cross Validation ###
# --
# train set
# =========
# Mean absolute error: 0.00927048323135482
# Mean squared error: 0.0008566428296583075
# Max error: 0.24403709549923502
# True value: 0.129717527140625
# Predicted value: -0.11431956835861001
# test set
# =========
# Mean absolute error: 0.008766272155827693
# Mean squared error: 0.0006309553128431272
# Max error: 0.15679945316905508
# True value: 2.4189376210078124
# Predicted value: 2.5757370741768675
# --
# ### Cross Validation ###
# --
# train set
# =========
# Mean absolute error: 0.008291797844658565
# Mean squared error: 0.000703924770321726
# Max error: 0.24403709549923502
# True value: 0.129717527140625
# Predicted value: -0.11431956835861001
# test set
# =========
# Mean absolute error: 0.011680085465734359
# Mean squared error: 0.0010856386258646213
# Max error: 0.1833128856915186
# True value: 0.476745360453125
# Predicted value: 0.6600582461446436
# --
# ### Cross Validation ###
# --
# train set
# =========
# Mean absolute error: 0.00901978032125284
# Mean squared error: 0.0008650258274339157
# Max error: 0.24403709549923502
# True value: 0.129717527140625
# Predicted value: -0.11431956835861001
# test set
# =========
# Mean absolute error: 0.009512683091698993
# Mean squared error: 0.0006059968420713702
# Max error: 0.12506241493539783
# True value: 5.9677824848984375
# Predicted value: 6.092844899833835
# --
# ### Cross Validation ###
# --
# train set
# =========
# Mean absolute error: 0.010299322864365131
# Mean squared error: 0.0009512666848702191
# Max error: 0.24403709549923502
# True value: 0.129717527140625
# Predicted value: -0.11431956835861001
# test set
# =========
# Mean absolute error: 0.0057031359756686325
# Mean squared error: 0.000349234289372706
# Max error: 0.13055149486611373
# True value: 1.205115005078125
# Predicted value: 1.3356664999442387

# %% [markdown]
# ### Gaussian

# %% [markdown]
# #### My Optimized Hyperparameters

# %%
kr_g = GridSearchCV(
    KernelRidge(kernel="rbf", gamma=0.1),
    param_grid={"alpha": np.logspace(-15, 0, 40), "gamma": np.logspace(-5, 1, 40)},
)

kr_g.fit(X_train.copy(), y_train.copy())
optimized_g = kr_g.best_estimator_
print(np.log10([optimized_g.alpha, optimized_g.gamma]), optimized_g.kernel)
# Out:
# [-9.23076923 -2.84615385] rbf

# %%
fig, ax =plt.subplots(1,1,figsize=(10,10))
pvt_g = pd.pivot_table(pd.DataFrame(kr_g.cv_results_), values='mean_test_score', index='param_alpha', columns='param_gamma')
sns.heatmap(pvt_g,ax=ax)
# Out:
# <AxesSubplot:xlabel='param_gamma', ylabel='param_alpha'>

# %%
model_g=KernelRidge(alpha=optimized_g.alpha, kernel=optimized_g.kernel, coef0=0, gamma=optimized_g.gamma)

# %%
model_g.fit(X_train.copy(), y_train.copy())
# Out:
# KernelRidge(alpha=5.878016072274924e-10, coef0=0, gamma=0.0014251026703029992,
#             kernel='rbf')

# %%
fit_test_g = model_g.predict(X_test.copy())
fit_train_g = model_g.predict(X_train.copy())

# %%
Utils.print_error(y_test, fit_test_g, "test set")
Utils.print_error(y_train, fit_train_g, "train set")
# Out:
# test set
# =========
# Mean absolute error: 0.02085448263801238
# Mean squared error: 0.00112459290439025
# Max error: 0.15019163147000625
# True value: 0.828152689140625
# Predicted value: 0.9783443206106313
# train set
# =========
# Mean absolute error: 0.0013648719398357122
# Mean squared error: 3.974624965527518e-06
# Max error: 0.007494470478792037
# True value: 1.7895364802929687
# Predicted value: 1.7820420098141767

# %% [markdown]
# ####  Cross Validation

# %%
score_g = cross_val_score(model_g, X, Y, cv=cv) 
print(score_g)
# Out:
# [0.99893143 0.99958929 0.99932676 0.99956325 0.99960829]

# %%
for train_index, test_index in cv.split(Y):
    fit_test = model_g.predict(X.copy()[test_index])
    fit_train = model_g.predict(X.copy()[train_index])
    
    print("--")
    print("### Cross Validation ###")
    print("--")
    Utils.print_error(Y.copy()[train_index], fit_train, "train set")
    Utils.print_error(Y.copy()[test_index], fit_test, "test set")
# Out:
# --
# ### Cross Validation ###
# --
# train set
# =========
# Mean absolute error: 0.006995239145867964
# Mean squared error: 0.0003531700591409564
# Max error: 0.15019163147000625
# True value: 0.828152689140625
# Predicted value: 0.9783443206106313
# test set
# =========
# Mean absolute error: 0.004091343804688731
# Mean squared error: 8.494287421575873e-05
# Max error: 0.06299581975728244
# True value: 0.0070270471875
# Predicted value: 0.07002286694478244
# --
# ### Cross Validation ###
# --
# train set
# =========
# Mean absolute error: 0.006592265254216181
# Mean squared error: 0.00030653144453302066
# Max error: 0.15019163147000625
# True value: 0.828152689140625
# Predicted value: 0.9783443206106313
# test set
# =========
# Mean absolute error: 0.005291107815093448
# Mean squared error: 0.00022379875140743176
# Max error: 0.11488909729949352
# True value: 0.00608887690625
# Predicted value: 0.12097797420574352
# --
# ### Cross Validation ###
# --
# train set
# =========
# Mean absolute error: 0.005948999525372635
# Mean squared error: 0.0002566467291095632
# Max error: 0.15019163147000625
# True value: 0.828152689140625
# Predicted value: 0.9783443206106313
# test set
# =========
# Mean absolute error: 0.0072062845141480664
# Mean squared error: 0.0003723191511772
# Max error: 0.11302505833382259
# True value: 1.0204101158125
# Predicted value: 0.9073850574786775
# --
# ### Cross Validation ###
# --
# train set
# =========
# Mean absolute error: 0.006210061893553056
# Mean squared error: 0.00030007353886305567
# Max error: 0.15019163147000625
# True value: 0.828152689140625
# Predicted value: 0.9783443206106313
# test set
# =========
# Mean absolute error: 0.00642903079341222
# Mean squared error: 0.00024302570922298436
# Max error: 0.0981564958991975
# True value: 0.8791921572929687
# Predicted value: 0.9773486531921662
# --
# ### Cross Validation ###
# --
# train set
# =========
# Mean absolute error: 0.006902699927336325
# Mean squared error: 0.0003305901624554312
# Max error: 0.15019163147000625
# True value: 0.828152689140625
# Predicted value: 0.9783443206106313
# test set
# =========
# Mean absolute error: 0.004366858282115165
# Mean squared error: 0.00015216938377835823
# Max error: 0.09815648658597176
# True value: 0.8791921572929687
# Predicted value: 0.9773486438789405

# %% [markdown]
# ### Laplacian

# %% [markdown]
# #### My Optimized Hyperparameters

# %%
kr_l = GridSearchCV(
    KernelRidge(kernel="laplacian", gamma=0.1),
    param_grid={"alpha": np.logspace(-20, 10, 40), "gamma": np.logspace(-10, 5, 40)},
)

kr_l.fit(X_train.copy(), y_train.copy())
optimized_l = kr_l.best_estimator_
print(np.log10([optimized_l.alpha, optimized_l.gamma]), optimized_l.kernel)
# Out:
# [-20.          -1.53846154] laplacian

# %%
fig, ax =plt.subplots(1,1,figsize=(10,10))
pvt_l = pd.pivot_table(pd.DataFrame(kr_l.cv_results_), values='mean_test_score', index='param_alpha', columns='param_gamma')
sns.heatmap(pvt_l,ax=ax)
# Out:
# <AxesSubplot:xlabel='param_gamma', ylabel='param_alpha'>

# %%
model_l=KernelRidge(alpha=optimized_l.alpha, kernel=optimized_l.kernel, coef0=0, gamma=optimized_l.gamma)

# %%
model_l.fit(X_train.copy(), y_train.copy())
# Out:
# KernelRidge(alpha=1e-20, coef0=0, gamma=0.028942661247167517,
#             kernel='laplacian')

# %%
fit_test_l = model_l.predict(X_test.copy())
fit_train_l = model_l.predict(X_train.copy())

# %%
Utils.print_error(y_test, fit_test_l, "test set")
Utils.print_error(y_train, fit_train_l, "train set")
# Out:
# test set
# =========
# Mean absolute error: 0.11464767646381747
# Mean squared error: 0.036461482732333315
# Max error: 1.081010348476802
# True value: 9.709621066839844
# Predicted value: 8.628610718363042
# train set
# =========
# Mean absolute error: 1.1022864440198304e-14
# Mean squared error: 1.9668742153286196e-28
# Max error: 5.10702591327572e-14
# True value: 3.46281768471875
# Predicted value: 3.462817684718801

# %% [markdown]
# #### Cross Validation

# %%
score_l = cross_val_score(model_l, X, Y, cv=cv) 
print(score_l)
# Out:
# [0.98515362 0.99009614 0.99165957 0.98740752 0.99167453]

# %%
 for train_index, test_index in cv.split(Y):
    fit_test = model_l.predict(X.copy()[test_index])
    fit_train = model_l.predict(X.copy()[train_index])
    
    print("--")
    print("### Cross Validation ###")
    print("--")
    Utils.print_error(Y.copy()[train_index], fit_train, "train set")
    Utils.print_error(Y.copy()[test_index], fit_test, "test set")
# Out:
# --
# ### Cross Validation ###
# --
# train set
# =========
# Mean absolute error: 0.03084614654544725
# Mean squared error: 0.00997149520738475
# Max error: 1.081010348476802
# True value: 9.709621066839844
# Predicted value: 8.628610718363042
# test set
# =========
# Mean absolute error: 0.02281028561263228
# Mean squared error: 0.006773622001255939
# Max error: 0.4493021082767745
# True value: 5.118190943445312
# Predicted value: 4.668888835168538
# --
# ### Cross Validation ###
# --
# train set
# =========
# Mean absolute error: 0.02949025592993595
# Mean squared error: 0.009986538235640498
# Max error: 1.081010348476802
# True value: 9.709621066839844
# Predicted value: 8.628610718363042
# test set
# =========
# Mean absolute error: 0.02684714176335904
# Mean squared error: 0.006728834803494512
# Max error: 0.6754772446491648
# True value: 4.136831806648438
# Predicted value: 4.812309051297603
# --
# ### Cross Validation ###
# --
# train set
# =========
# Mean absolute error: 0.029610600807654815
# Mean squared error: 0.010428012126816415
# Max error: 1.081010348476802
# True value: 9.709621066839844
# Predicted value: 8.628610718363042
# test set
# =========
# Mean absolute error: 0.026488842241059737
# Mean squared error: 0.0054144466274934815
# Max error: 0.429583416604554
# True value: 3.16127982903125
# Predicted value: 2.731696412426696
# --
# ### Cross Validation ###
# --
# train set
# =========
# Mean absolute error: 0.02982346722879601
# Mean squared error: 0.010059305906332926
# Max error: 1.081010348476802
# True value: 9.709621066839844
# Predicted value: 8.628610718363042
# test set
# =========
# Mean absolute error: 0.025855080850843922
# Mean squared error: 0.006512185602114775
# Max error: 0.6754772446491648
# True value: 4.136831806648438
# Predicted value: 4.812309051297603
# --
# ### Cross Validation ###
# --
# train set
# =========
# Mean absolute error: 0.03175948553220083
# Mean squared error: 0.010787467515250062
# Max error: 1.081010348476802
# True value: 9.709621066839844
# Predicted value: 8.628610718363042
# test set
# =========
# Mean absolute error: 0.020091026356615766
# Mean squared error: 0.004344249902838747
# Max error: 0.4493021082767745
# True value: 5.118190943445312
# Predicted value: 4.668888835168538

# %% [markdown]
# ### Comparison and Analyze

# %%
err_train_p3 = Utils.compute_error(y_train, fit_train_p3)
err_train_p2 = Utils.compute_error(y_train, fit_train_p2)
err_train_g = Utils.compute_error(y_train, fit_train_g)
err_train_l = Utils.compute_error(y_train, fit_train_l)

err_train_p3 = np.asarray(err_train_p3)
err_train_p2 = np.asarray(err_train_p2)
err_train_g = np.asarray(err_train_g)
err_train_l = np.asarray(err_train_l)

err_train = np.stack((err_train_p3, err_train_p2, err_train_g, err_train_l), axis=1)

######

err_test_p3 = Utils.compute_error(y_test, fit_test_p3)
err_test_p2 = Utils.compute_error(y_test, fit_test_p2)
err_test_g = Utils.compute_error(y_test, fit_test_g)
err_test_l = Utils.compute_error(y_test, fit_test_l)

err_test_p3 = np.asarray(err_test_p3)
err_test_p2 = np.asarray(err_test_p2)
err_test_g = np.asarray(err_test_g)
err_test_l = np.asarray(err_test_l)

err_test = np.stack((err_test_p3, err_test_p2, err_test_g, err_test_l), axis=1)

# %%
column_labels=["Polynomial 3", "Polynomial 2", "Gaussian", "Laplacian"]
df_train=pd.DataFrame(err_train,columns=column_labels)
df_test=pd.DataFrame(err_test,columns=column_labels)
df_train.update(df_train[["Polynomial 3", "Polynomial 2", "Gaussian", "Laplacian"]].applymap('{:,.6f}'.format))
df_test.update(df_test[["Polynomial 3", "Polynomial 2", "Gaussian", "Laplacian"]].applymap('{:,.6f}'.format))

# %%
fig, ax =plt.subplots(2,1,figsize=(25,4))
ax[0].axis('tight')
ax[0].axis('off')
ax[1].axis('tight')
ax[1].axis('off')
ax[0].set_title("Train Set")
ax[1].set_title("Test Set")
ax[0].table(cellText=df_train.values,colLabels=df_train.columns,rowLabels=["MAE","MSE","ME","True","Predict"],loc="center",cellLoc='center')
ax[1].table(cellText=df_test.values,colLabels=df_test.columns,rowLabels=["MAE","MSE","ME","True","Predict"],loc="center",cellLoc='center')
